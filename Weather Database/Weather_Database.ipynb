# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import time
from datetime import datetime

import requests

from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
#Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 2 of Set 1 | vostok
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | nioro
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | ishigaki
# Processing Record 15 of Set 1 | koudougou
# Processing Record 16 of Set 1 | chengde
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | bequimao
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | ndouci
# City not found. Skipping...
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | buckeye
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | ayan
# Processing Record 32 of Set 1 | bichura
# Processing Record 33 of Set 1 | suluq
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | chardara
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | kondratovo
# Processing Record 41 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | saint-joseph
# Processing Record 45 of Set 1 | srednekolymsk
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | santa teresa
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | leningradskiy
# Processing Record 5 of Set 2 | port macquarie
# Processing Record 6 of Set 2 | lebanon
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | hambantota
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | aranos
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | portland
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | scalea
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | shimoda
# Processing Record 19 of Set 2 | burgeo
# Processing Record 20 of Set 2 | mitsamiouli
# Processing Record 21 of Set 2 | port augusta
# Processing Record 22 of Set 2 | ho
# City not found. Skipping...
# Processing Record 23 of Set 2 | koslan
# Processing Record 24 of Set 2 | kibala
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | vitim
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | manturovo
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | taree
# Processing Record 34 of Set 2 | bay roberts
# Processing Record 35 of Set 2 | nanakuli
# Processing Record 36 of Set 2 | vestmanna
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | margate
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | sattahip
# Processing Record 42 of Set 2 | north bend
# Processing Record 43 of Set 2 | astorga
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | kutum
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | sudbury
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | gubkinskiy
# Processing Record 2 of Set 3 | evensk
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | bafoulabe
# Processing Record 5 of Set 3 | pecos
# Processing Record 6 of Set 3 | nouadhibou
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | westport
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | jimenez
# Processing Record 13 of Set 3 | port hedland
# Processing Record 14 of Set 3 | guerrero negro
# Processing Record 15 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | union
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | ravar
# Processing Record 20 of Set 3 | charters towers
# Processing Record 21 of Set 3 | coahuayana
# Processing Record 22 of Set 3 | riberalta
# Processing Record 23 of Set 3 | ventersburg
# Processing Record 24 of Set 3 | whitehorse
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | cololaca
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | alyangula
# Processing Record 29 of Set 3 | namibe
# Processing Record 30 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | altay
# Processing Record 34 of Set 3 | denpasar
# Processing Record 35 of Set 3 | dingle
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | baruun-urt
# Processing Record 39 of Set 3 | sai buri
# Processing Record 40 of Set 3 | hirara
# Processing Record 41 of Set 3 | kuryk
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | amga
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 3 | bakel
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | dindori
# Processing Record 49 of Set 3 | makakilo city
# Processing Record 50 of Set 3 | vermillion
# Processing Record 1 of Set 4 | beyneu
# Processing Record 2 of Set 4 | san jose
# Processing Record 3 of Set 4 | puerto suarez
# Processing Record 4 of Set 4 | barcelona
# Processing Record 5 of Set 4 | rodrigues alves
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | manta
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | kailua
# Processing Record 10 of Set 4 | khlevnoye
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | isangel
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | inyonga
# Processing Record 15 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | tucuman
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | stawell
# Processing Record 25 of Set 4 | ilo
# Processing Record 26 of Set 4 | alekseyevka
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 4 | havre-saint-pierre
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | wattegama
# Processing Record 33 of Set 4 | havoysund
# Processing Record 34 of Set 4 | ahuimanu
# Processing Record 35 of Set 4 | dryden
# Processing Record 36 of Set 4 | erenhot
# Processing Record 37 of Set 4 | talnakh
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | samarai
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | berlevag
# Processing Record 42 of Set 4 | abonnema
# Processing Record 43 of Set 4 | strezhevoy
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | lima
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | abu zabad
# Processing Record 48 of Set 4 | san policarpo
# Processing Record 49 of Set 4 | alice springs
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | pacific grove
# Processing Record 3 of Set 5 | snezhnogorsk
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | ginda
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | porto novo
# Processing Record 8 of Set 5 | qasigiannguit
# Processing Record 9 of Set 5 | manono
# Processing Record 10 of Set 5 | kirakira
# Processing Record 11 of Set 5 | chicama
# Processing Record 12 of Set 5 | port lincoln
# Processing Record 13 of Set 5 | tacoronte
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | buin
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | lasa
# Processing Record 20 of Set 5 | atar
# Processing Record 21 of Set 5 | yen bai
# Processing Record 22 of Set 5 | safaga
# Processing Record 23 of Set 5 | casablanca
# Processing Record 24 of Set 5 | luwuk
# Processing Record 25 of Set 5 | algiers
# Processing Record 26 of Set 5 | dali
# Processing Record 27 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 5 | chiriguana
# Processing Record 29 of Set 5 | yangambi
# Processing Record 30 of Set 5 | ilula
# Processing Record 31 of Set 5 | phulji
# Processing Record 32 of Set 5 | touros
# Processing Record 33 of Set 5 | ingham
# Processing Record 34 of Set 5 | zhongshu
# Processing Record 35 of Set 5 | salinopolis
# Processing Record 36 of Set 5 | sinop
# Processing Record 37 of Set 5 | hutchinson
# Processing Record 38 of Set 5 | taybad
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | mauriti
# Processing Record 41 of Set 5 | cam ranh
# Processing Record 42 of Set 5 | miri
# Processing Record 43 of Set 5 | yerbogachen
# Processing Record 44 of Set 5 | mahon
# Processing Record 45 of Set 5 | probolinggo
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | pathein
# Processing Record 48 of Set 5 | yulara
# Processing Record 49 of Set 5 | bonavista
# Processing Record 50 of Set 5 | muros
# Processing Record 1 of Set 6 | quatre cocos
# Processing Record 2 of Set 6 | orzhytsya
# Processing Record 3 of Set 6 | cedar city
# Processing Record 4 of Set 6 | luzhou
# Processing Record 5 of Set 6 | zima
# Processing Record 6 of Set 6 | sondrio
# Processing Record 7 of Set 6 | honningsvag
# Processing Record 8 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 9 of Set 6 | panguna
# Processing Record 10 of Set 6 | sorland
# Processing Record 11 of Set 6 | saint joseph
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | awjilah
# Processing Record 14 of Set 6 | puerto carreno
# Processing Record 15 of Set 6 | gillette
# Processing Record 16 of Set 6 | raga
# Processing Record 17 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 18 of Set 6 | san buenaventura
# Processing Record 19 of Set 6 | zhangye
# Processing Record 20 of Set 6 | bara
# Processing Record 21 of Set 6 | salinas
# Processing Record 22 of Set 6 | ambulu
# Processing Record 23 of Set 6 | ntoum
# Processing Record 24 of Set 6 | isla vista
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | abu samrah
# Processing Record 27 of Set 6 | emba
# Processing Record 28 of Set 6 | san sebastian
# Processing Record 29 of Set 6 | daru
# Processing Record 30 of Set 6 | chifeng
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | galeana
# Processing Record 33 of Set 6 | jiazi
# Processing Record 34 of Set 6 | san andres
# Processing Record 35 of Set 6 | mmabatho
# Processing Record 36 of Set 6 | atasu
# Processing Record 37 of Set 6 | inta
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | oliver
# Processing Record 40 of Set 6 | cody
# Processing Record 41 of Set 6 | newport
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | trairi
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 6 | kuah
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | dogondoutchi
# Processing Record 49 of Set 6 | jaque
# Processing Record 50 of Set 6 | beringovskiy
# Processing Record 1 of Set 7 | huescar
# Processing Record 2 of Set 7 | sept-iles
# Processing Record 3 of Set 7 | astaneh-ye ashrafiyeh
# Processing Record 4 of Set 7 | long xuyen
# Processing Record 5 of Set 7 | jumla
# Processing Record 6 of Set 7 | yeniseysk
# Processing Record 7 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 8 of Set 7 | zhigansk
# Processing Record 9 of Set 7 | flinders
# Processing Record 10 of Set 7 | karwar
# Processing Record 11 of Set 7 | sivaki
# Processing Record 12 of Set 7 | caibarien
# Processing Record 13 of Set 7 | chumphon
# Processing Record 14 of Set 7 | kilrush
# Processing Record 15 of Set 7 | selty
# Processing Record 16 of Set 7 | goundam
# Processing Record 17 of Set 7 | aitape
# Processing Record 18 of Set 7 | lingao
# Processing Record 19 of Set 7 | jalu
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | port elizabeth
# Processing Record 22 of Set 7 | lerwick
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | koumac
# Processing Record 26 of Set 7 | manicore
# Processing Record 27 of Set 7 | marzuq
# Processing Record 28 of Set 7 | namatanai
# Processing Record 29 of Set 7 | mar del plata
# Processing Record 30 of Set 7 | tromso
# Processing Record 31 of Set 7 | labuhan
# Processing Record 32 of Set 7 | mayo
# Processing Record 33 of Set 7 | hastings
# Processing Record 34 of Set 7 | biak
# Processing Record 35 of Set 7 | lao cai
# Processing Record 36 of Set 7 | buala
# Processing Record 37 of Set 7 | sao filipe
# Processing Record 38 of Set 7 | cidreira
# Processing Record 39 of Set 7 | meulaboh
# Processing Record 40 of Set 7 | baykit
# Processing Record 41 of Set 7 | tuckahoe
# Processing Record 42 of Set 7 | mashhad
# Processing Record 43 of Set 7 | anadyr
# Processing Record 44 of Set 7 | rurrenabaque
# Processing Record 45 of Set 7 | dutse
# Processing Record 46 of Set 7 | tessalit
# Processing Record 47 of Set 7 | puerto cabezas
# Processing Record 48 of Set 7 | leh
# Processing Record 49 of Set 7 | orcopampa
# Processing Record 50 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 8 | batemans bay
# Processing Record 2 of Set 8 | krasnotorka
# Processing Record 3 of Set 8 | roura
# Processing Record 4 of Set 8 | sabzevar
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | lotoshino
# Processing Record 7 of Set 8 | mogadishu
# Processing Record 8 of Set 8 | okhotsk
# Processing Record 9 of Set 8 | bosaso
# Processing Record 10 of Set 8 | dzhebariki-khaya
# Processing Record 11 of Set 8 | portage
# Processing Record 12 of Set 8 | haradok
# Processing Record 13 of Set 8 | lubumbashi
# Processing Record 14 of Set 8 | monrovia
# Processing Record 15 of Set 8 | kovur
# Processing Record 16 of Set 8 | salihorsk
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | kota kinabalu
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | aswan
# Processing Record 21 of Set 8 | thai nguyen
# Processing Record 22 of Set 8 | mushie
# Processing Record 23 of Set 8 | severo-kurilsk
# Processing Record 24 of Set 8 | roma
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | poum
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | zakamensk
# Processing Record 30 of Set 8 | bandarbeyla
# Processing Record 31 of Set 8 | inhambane
# Processing Record 32 of Set 8 | pouembout
# Processing Record 33 of Set 8 | dayong
# Processing Record 34 of Set 8 | esna
# Processing Record 35 of Set 8 | dunmore town
# Processing Record 36 of Set 8 | marawi
# Processing Record 37 of Set 8 | yueyang
# Processing Record 38 of Set 8 | ozerne
# Processing Record 39 of Set 8 | ust-tsilma
# Processing Record 40 of Set 8 | aykhal
# Processing Record 41 of Set 8 | ocos
# Processing Record 42 of Set 8 | paciran
# Processing Record 43 of Set 8 | katangli
# Processing Record 44 of Set 8 | tambovka
# Processing Record 45 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 8 | noumea
# Processing Record 47 of Set 8 | savannah bight
# Processing Record 48 of Set 8 | nisia floresta
# Processing Record 49 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 8 | camopi
# Processing Record 1 of Set 9 | solnechnyy
# Processing Record 2 of Set 9 | tiznit
# Processing Record 3 of Set 9 | ust-nera
# Processing Record 4 of Set 9 | brigantine
# Processing Record 5 of Set 9 | ballina
# Processing Record 6 of Set 9 | vila velha
# Processing Record 7 of Set 9 | vardo
# Processing Record 8 of Set 9 | salalah
# Processing Record 9 of Set 9 | gushikawa
# Processing Record 10 of Set 9 | skjervoy
# Processing Record 11 of Set 9 | inhambupe
# Processing Record 12 of Set 9 | novosokolniki
# Processing Record 13 of Set 9 | manokwari
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | kavieng
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | verdun
# Processing Record 18 of Set 9 | sao joao da barra
# Processing Record 19 of Set 9 | richards bay
# Processing Record 20 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 9 | port-cartier
# Processing Record 22 of Set 9 | bonthe
# Processing Record 23 of Set 9 | borujerd
# Processing Record 24 of Set 9 | novo aripuana
# Processing Record 25 of Set 9 | williston
# Processing Record 26 of Set 9 | rocha
# Processing Record 27 of Set 9 | arenapolis
# Processing Record 28 of Set 9 | lagoa
# Processing Record 29 of Set 9 | caraballeda
# Processing Record 30 of Set 9 | deputatskiy
# Processing Record 31 of Set 9 | mataram
# Processing Record 32 of Set 9 | uzice
# Processing Record 33 of Set 9 | linda
# Processing Record 34 of Set 9 | plouzane
# Processing Record 35 of Set 9 | sandwick
# Processing Record 36 of Set 9 | beloha
# Processing Record 37 of Set 9 | asyut
# Processing Record 38 of Set 9 | poquoson
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 | manaus
# Processing Record 41 of Set 9 | asosa
# Processing Record 42 of Set 9 | cayenne
# Processing Record 43 of Set 9 | maarianhamina
# Processing Record 44 of Set 9 | ossora
# Processing Record 45 of Set 9 | poiana teiului
# Processing Record 46 of Set 9 | mazamari
# Processing Record 47 of Set 9 | tilichiki
# Processing Record 48 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 9 | mikhaylovka
# Processing Record 50 of Set 9 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 1 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 2 of Set 10 | dolgoderevenskoye
# Processing Record 3 of Set 10 | khvoynaya
# Processing Record 4 of Set 10 | rincon de la victoria
# Processing Record 5 of Set 10 | kon tum
# Processing Record 6 of Set 10 | sobolevo
# Processing Record 7 of Set 10 | swift current
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | chissamba
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 10 | byron bay
# Processing Record 14 of Set 10 | iquique
# Processing Record 15 of Set 10 | bansi
# Processing Record 16 of Set 10 | galesong
# Processing Record 17 of Set 10 | scottsbluff
# Processing Record 18 of Set 10 | saint george
# Processing Record 19 of Set 10 | tamandare
# Processing Record 20 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 10 | erdaojiang
# Processing Record 22 of Set 10 | leshukonskoye
# Processing Record 23 of Set 10 | ornskoldsvik
# Processing Record 24 of Set 10 | ivanteyevka
# Processing Record 25 of Set 10 | iralaya
# Processing Record 26 of Set 10 | temerloh
# Processing Record 27 of Set 10 | iqaluit
# Processing Record 28 of Set 10 | dunmore east
# Processing Record 29 of Set 10 | narsaq
# Processing Record 30 of Set 10 | tezu
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | tarata
# Processing Record 33 of Set 10 | parrita
# Processing Record 34 of Set 10 | port-gentil
# Processing Record 35 of Set 10 | chippewa falls
# Processing Record 36 of Set 10 | limoux
# Processing Record 37 of Set 10 | oum hadjer
# Processing Record 38 of Set 10 | kommunisticheskiy
# Processing Record 39 of Set 10 | camocim
# Processing Record 40 of Set 10 | san patricio
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | egvekinot
# Processing Record 43 of Set 10 | garden city
# Processing Record 44 of Set 10 | estelle
# Processing Record 45 of Set 10 | mardan
# Processing Record 46 of Set 10 | riyadh
# Processing Record 47 of Set 10 | uvalde
# Processing Record 48 of Set 10 | biltine
# Processing Record 49 of Set 10 | ostrovnoy
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | steamboat springs
# Processing Record 2 of Set 11 | urengoy
# Processing Record 3 of Set 11 | gazanjyk
# Processing Record 4 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 11 | pangody
# Processing Record 6 of Set 11 | bilma
# Processing Record 7 of Set 11 | cervia
# Processing Record 8 of Set 11 | laguna
# Processing Record 9 of Set 11 | lata
# Processing Record 10 of Set 11 | mongo
# Processing Record 11 of Set 11 | bodden town
# Processing Record 12 of Set 11 | bandarban
# Processing Record 13 of Set 11 | shelburne
# Processing Record 14 of Set 11 | salym
# Processing Record 15 of Set 11 | popondetta
# Processing Record 16 of Set 11 | myaundzha
# Processing Record 17 of Set 11 | mount isa
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | illescas
# Processing Record 20 of Set 11 | kysyl-syr
# Processing Record 21 of Set 11 | raudeberg
# Processing Record 22 of Set 11 | raditsa-krylovka
# Processing Record 23 of Set 11 | markala
# Processing Record 24 of Set 11 | karoi
# Processing Record 25 of Set 11 | togur
# Processing Record 26 of Set 11 | mountain home
# Processing Record 27 of Set 11 | dargaville
# Processing Record 28 of Set 11 | at-bashi
# Processing Record 29 of Set 11 | port blair
# Processing Record 30 of Set 11 | plettenberg bay
# Processing Record 31 of Set 11 | luganville
# Processing Record 32 of Set 11 | rockland
# Processing Record 33 of Set 11 | jaypur
# Processing Record 34 of Set 11 | nogent-le-rotrou
# Processing Record 35 of Set 11 | tera
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | flin flon
# Processing Record 38 of Set 11 | orizatlan
# Processing Record 39 of Set 11 | hovd
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | rio gallegos
# Processing Record 42 of Set 11 | lugovoy
# Processing Record 43 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 11 | turan
# Processing Record 45 of Set 11 | chillicothe
# Processing Record 46 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 11 | iguape
# Processing Record 48 of Set 11 | puerto narino
# Processing Record 49 of Set 11 | roald
# Processing Record 50 of Set 11 | hopkinsville
# Processing Record 1 of Set 12 | acarau
# Processing Record 2 of Set 12 | ottumwa
# Processing Record 3 of Set 12 | chico
# Processing Record 4 of Set 12 | mae hong son
# Processing Record 5 of Set 12 | omsukchan
# Processing Record 6 of Set 12 | kajaani
# Processing Record 7 of Set 12 | espanola
# Processing Record 8 of Set 12 | vanimo
# Processing Record 9 of Set 12 | harper
# Processing Record 10 of Set 12 | maykor
# Processing Record 11 of Set 12 | birao
# Processing Record 12 of Set 12 | taga
# Processing Record 13 of Set 12 | umm lajj
# Processing Record 14 of Set 12 | lundazi
# Processing Record 15 of Set 12 | garowe
# Processing Record 16 of Set 12 | mehamn
# Processing Record 17 of Set 12 | karlstad
# Processing Record 18 of Set 12 | charala
# Processing Record 19 of Set 12 | kununurra
# Processing Record 20 of Set 12 | tautira
# Processing Record 21 of Set 12 | nenjiang
# Processing Record 22 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 12 | yomou
# Processing Record 25 of Set 12 | concepcion
# Processing Record 26 of Set 12 | bilibino
# Processing Record 27 of Set 12 | mokhsogollokh
# Processing Record 28 of Set 12 | odienne
# Processing Record 29 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 12 | ulaangom
# Processing Record 31 of Set 12 | salekhard
# Processing Record 32 of Set 12 | thunder bay
# Processing Record 33 of Set 12 | celestun
# Processing Record 34 of Set 12 | saint-francois
# Processing Record 35 of Set 12 | san lawrenz
# Processing Record 36 of Set 12 | araouane
# Processing Record 37 of Set 12 | saint-die
# City not found. Skipping...
# Processing Record 38 of Set 12 | qandala
# Processing Record 39 of Set 12 | kimbe
# Processing Record 40 of Set 12 | mossoro
# Processing Record 41 of Set 12 | kralendijk
# Processing Record 42 of Set 12 | abu dhabi
# Processing Record 43 of Set 12 | de-kastri
# Processing Record 44 of Set 12 | udachnyy
# Processing Record 45 of Set 12 | fairbanks
# Processing Record 46 of Set 12 | kashi
# Processing Record 47 of Set 12 | panubigan
# Processing Record 48 of Set 12 | maldonado
# Processing Record 49 of Set 12 | pyryatyn
# Processing Record 50 of Set 12 | springbok
# Processing Record 1 of Set 13 | burnie
# Processing Record 2 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 13 | planaltina
# Processing Record 4 of Set 13 | lodwar
# Processing Record 5 of Set 13 | las vegas
# Processing Record 6 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 13 | eenhana
# Processing Record 8 of Set 13 | kamenka
# Processing Record 9 of Set 13 | kargil
# Processing Record 10 of Set 13 | matamoros
# Processing Record 11 of Set 13 | pingliang
# Processing Record 12 of Set 13 | bloomington
# Processing Record 13 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 14 of Set 13 | ambon
# Processing Record 15 of Set 13 | chuy
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | abnub
# Processing Record 18 of Set 13 | methoni
# Processing Record 19 of Set 13 | bubaque
# Processing Record 20 of Set 13 | colombo
# Processing Record 21 of Set 13 | nizwa
# Processing Record 22 of Set 13 | tiassale
# Processing Record 23 of Set 13 | ziro
# Processing Record 24 of Set 13 | sabha
# Processing Record 25 of Set 13 | nhulunbuy
# Processing Record 26 of Set 13 | baisoara
# Processing Record 27 of Set 13 | shahdadkot
# Processing Record 28 of Set 13 | mae sai
# Processing Record 29 of Set 13 | seredeyskiy
# Processing Record 30 of Set 13 | tapes
# Processing Record 31 of Set 13 | helong
# Processing Record 32 of Set 13 | troitskoye
# Processing Record 33 of Set 13 | saint-pierre
# Processing Record 34 of Set 13 | mana
# Processing Record 35 of Set 13 | mala
# Processing Record 36 of Set 13 | pochutla
# Processing Record 37 of Set 13 | bundaberg
# Processing Record 38 of Set 13 | oranjemund
# Processing Record 39 of Set 13 | rorvik
# Processing Record 40 of Set 13 | murray bridge
# Processing Record 41 of Set 13 | ankazoabo
# Processing Record 42 of Set 13 | turukhansk
# Processing Record 43 of Set 13 | saint anthony
# Processing Record 44 of Set 13 | maglie
# Processing Record 45 of Set 13 | marrakesh
# Processing Record 46 of Set 13 | lazaro cardenas
# Processing Record 47 of Set 13 | den helder
# Processing Record 48 of Set 13 | pizarro
# Processing Record 49 of Set 13 | rovaniemi
# Processing Record 50 of Set 13 | fethiye
# Processing Record 1 of Set 14 | rochegda
# Processing Record 2 of Set 14 | along
# Processing Record 3 of Set 14 | francia
# Processing Record 4 of Set 14 | vilhena
# Processing Record 5 of Set 14 | ola
# Processing Record 6 of Set 14 | bondo
# Processing Record 7 of Set 14 | slobodskoy
# Processing Record 8 of Set 14 | maceio
# Processing Record 9 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 14 | melilla
# Processing Record 11 of Set 14 | kostino
# Processing Record 12 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 14 | mattru
# Processing Record 14 of Set 14 | dabola
# Processing Record 15 of Set 14 | kokstad
# Processing Record 16 of Set 14 | banda aceh
# Processing Record 17 of Set 14 | isabela
# Processing Record 18 of Set 14 | blackwater
# Processing Record 19 of Set 14 | gouyave
# Processing Record 20 of Set 14 | susangerd
# Processing Record 21 of Set 14 | nurota
# Processing Record 22 of Set 14 | boca do acre
# Processing Record 23 of Set 14 | trelew
# Processing Record 24 of Set 14 | ilinskiy
# Processing Record 25 of Set 14 | henties bay
# Processing Record 26 of Set 14 | malibu
# Processing Record 27 of Set 14 | istok
# Processing Record 28 of Set 14 | damoh
# Processing Record 29 of Set 14 | itarema
# Processing Record 30 of Set 14 | rawson
# Processing Record 31 of Set 14 | emmett
# Processing Record 32 of Set 14 | kholodnyy
# Processing Record 33 of Set 14 | malihabad
# Processing Record 34 of Set 14 | ialibu
# Processing Record 35 of Set 14 | kunya
# Processing Record 36 of Set 14 | griffith
# Processing Record 37 of Set 14 | aksarka
# Processing Record 38 of Set 14 | gondanglegi
# Processing Record 39 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | galle
# Processing Record 41 of Set 14 | oyama
# Processing Record 42 of Set 14 | grand gaube
# Processing Record 43 of Set 14 | hervey bay
# Processing Record 44 of Set 14 | maniitsoq
# Processing Record 45 of Set 14 | ocampo
# Processing Record 46 of Set 14 | kenai
# Processing Record 47 of Set 14 | sao paulo de olivenca
# Processing Record 48 of Set 14 | saint-felicien
# Processing Record 49 of Set 14 | alofi
# Processing Record 50 of Set 14 | aksha
# Processing Record 1 of Set 15 | bismarck
# Processing Record 2 of Set 15 | barkly west
# Processing Record 3 of Set 15 | shenjiamen
# Processing Record 4 of Set 15 | talcahuano
# Processing Record 5 of Set 15 | nome
# Processing Record 6 of Set 15 | bam
# Processing Record 7 of Set 15 | cerkezkoy
# Processing Record 8 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 15 | maymyo
# Processing Record 10 of Set 15 | matagami
# Processing Record 11 of Set 15 | lorengau
# Processing Record 12 of Set 15 | palimbang
# Processing Record 13 of Set 15 | arnedo
# Processing Record 14 of Set 15 | ivybridge
# Processing Record 15 of Set 15 | santa maria
# Processing Record 16 of Set 15 | fort-shevchenko
# Processing Record 17 of Set 15 | melun
# Processing Record 18 of Set 15 | zhigalovo
# Processing Record 19 of Set 15 | ulaanbaatar
# Processing Record 20 of Set 15 | gebre guracha
# Processing Record 21 of Set 15 | sibi
# Processing Record 22 of Set 15 | key west
# Processing Record 23 of Set 15 | dehloran
# Processing Record 24 of Set 15 | sampang
# Processing Record 25 of Set 15 | takaka
# Processing Record 26 of Set 15 | lungi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vostok  46.4856  135.8833     19.89        84          12
# 1          Bethel  41.3712  -73.4140     54.03        39           0
# 2           Bluff -46.6000  168.3333     57.15        72          79
# 3         Ahipara -35.1667  173.1667     62.37        90         100
# 4          Castro -24.7911  -50.0119     63.12        87         100
# 5       Busselton -33.6500  115.3333     70.63        79         100
# 6           Nioro  13.3500  -15.7500     88.75        25           7
# 7      Butaritari   3.0707  172.7902     81.37        76          73
# 8    Puerto Ayora  -0.7393  -90.3518     85.96        92          56
# 9  Ribeira Grande  38.5167  -28.7000     61.20        67          40
#
#    Wind Speed Country                 Date
# 0        7.18      RU  2022-04-02 19:21:55
# 1        8.05      US  2022-04-02 19:21:56
# 2       20.49      NZ  2022-04-02 19:17:23
# 3        3.02      NZ  2022-04-02 19:21:56
# 4        7.52      BR  2022-04-02 19:21:56
# 5        8.25      AU  2022-04-02 19:21:57
# 6       14.45      GM  2022-04-02 19:21:57
# 7       16.22      KI  2022-04-02 19:18:06
# 8        5.01      EC  2022-04-02 19:21:58
# 9       11.50      PT  2022-04-02 19:18:31

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2616/2300452997.py in <module>
#       1 # Export the City_Data into a CSV.
# ----> 2 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/Weather_Database.csv'
