# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import time
from datetime import datetime

import requests

from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
#Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | coahuayana
# Processing Record 3 of Set 1 | pacifica
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | kenai
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | maceio
# Processing Record 10 of Set 1 | ancud
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | port blair
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | vardo
# Processing Record 17 of Set 1 | kavieng
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | constitucion
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 1 | lata
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | tura
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | vila franca do campo
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | asau
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | hofn
# Processing Record 45 of Set 1 | port hedland
# Processing Record 46 of Set 1 | mato verde
# Processing Record 47 of Set 1 | waipawa
# Processing Record 48 of Set 1 | villazon
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | spirit river
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | bonfim
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | morganton
# Processing Record 10 of Set 2 | jamalpur
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | komsomolskiy
# Processing Record 13 of Set 2 | tambura
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | chazuta
# Processing Record 16 of Set 2 | dingle
# Processing Record 17 of Set 2 | madera
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | mitsamiouli
# Processing Record 21 of Set 2 | zhigansk
# Processing Record 22 of Set 2 | payo
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | ayorou
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | fort nelson
# Processing Record 30 of Set 2 | tacuarembo
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | ningyang
# Processing Record 33 of Set 2 | atar
# Processing Record 34 of Set 2 | half moon bay
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | cururupu
# Processing Record 37 of Set 2 | fairbanks
# Processing Record 38 of Set 2 | pascagoula
# Processing Record 39 of Set 2 | sinegorye
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | kiama
# Processing Record 43 of Set 2 | grand gaube
# Processing Record 44 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | san julian
# Processing Record 47 of Set 2 | najran
# Processing Record 48 of Set 2 | ada
# Processing Record 49 of Set 2 | ngunguru
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | garwolin
# Processing Record 2 of Set 3 | haverfordwest
# Processing Record 3 of Set 3 | mangan
# Processing Record 4 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | roald
# Processing Record 8 of Set 3 | cap malheureux
# Processing Record 9 of Set 3 | flin flon
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | mata
# Processing Record 12 of Set 3 | ayr
# Processing Record 13 of Set 3 | pacific grove
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | haines junction
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | waddan
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | hermanus
# Processing Record 22 of Set 3 | new norfolk
# Processing Record 23 of Set 3 | yongan
# Processing Record 24 of Set 3 | camacha
# Processing Record 25 of Set 3 | tungor
# Processing Record 26 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | thinadhoo
# Processing Record 31 of Set 3 | valparaiso
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | kloulklubed
# Processing Record 34 of Set 3 | kochevo
# Processing Record 35 of Set 3 | hailey
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | galesong
# Processing Record 38 of Set 3 | hami
# Processing Record 39 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 3 | henties bay
# Processing Record 41 of Set 3 | butler
# Processing Record 42 of Set 3 | bonavista
# Processing Record 43 of Set 3 | ruteng
# Processing Record 44 of Set 3 | el alto
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | northam
# Processing Record 47 of Set 3 | dauphin
# Processing Record 48 of Set 3 | iquitos
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | ilebo
# Processing Record 1 of Set 4 | mabaruma
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | qasigiannguit
# Processing Record 4 of Set 4 | opatija
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | puerto ayora
# Processing Record 7 of Set 4 | helena
# Processing Record 8 of Set 4 | steamboat springs
# Processing Record 9 of Set 4 | baghmara
# Processing Record 10 of Set 4 | manavalakurichi
# Processing Record 11 of Set 4 | sur
# Processing Record 12 of Set 4 | sun city west
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | saint-lo
# Processing Record 15 of Set 4 | portland
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | douentza
# Processing Record 18 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 23 of Set 4 | eirunepe
# Processing Record 24 of Set 4 | fallon
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | youkounkoun
# Processing Record 27 of Set 4 | lazaro cardenas
# Processing Record 28 of Set 4 | hirara
# Processing Record 29 of Set 4 | saint-francois
# Processing Record 30 of Set 4 | minden
# Processing Record 31 of Set 4 | harpanahalli
# Processing Record 32 of Set 4 | lasa
# Processing Record 33 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | belyy yar
# Processing Record 37 of Set 4 | enid
# Processing Record 38 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 4 | sabha
# Processing Record 40 of Set 4 | brae
# Processing Record 41 of Set 4 | melfi
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | alamos
# Processing Record 44 of Set 4 | nikolskoye
# Processing Record 45 of Set 4 | dawlatabad
# Processing Record 46 of Set 4 | gradignan
# Processing Record 47 of Set 4 | evensk
# Processing Record 48 of Set 4 | sucua
# Processing Record 49 of Set 4 | banda aceh
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | moron
# Processing Record 3 of Set 5 | kahului
# Processing Record 4 of Set 5 | faanui
# Processing Record 5 of Set 5 | san ignacio
# Processing Record 6 of Set 5 | chimoio
# Processing Record 7 of Set 5 | port lincoln
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | yar-sale
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | berdigestyakh
# Processing Record 16 of Set 5 | serik
# Processing Record 17 of Set 5 | salalah
# Processing Record 18 of Set 5 | taboga
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | kovernino
# Processing Record 22 of Set 5 | toropets
# Processing Record 23 of Set 5 | muli
# Processing Record 24 of Set 5 | calvinia
# Processing Record 25 of Set 5 | manaskent
# Processing Record 26 of Set 5 | coihaique
# Processing Record 27 of Set 5 | umtata
# Processing Record 28 of Set 5 | uddevalla
# Processing Record 29 of Set 5 | banjar
# Processing Record 30 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 5 | verkhnetulomskiy
# Processing Record 32 of Set 5 | sao joao da barra
# Processing Record 33 of Set 5 | srivardhan
# Processing Record 34 of Set 5 | kazerun
# Processing Record 35 of Set 5 | luderitz
# Processing Record 36 of Set 5 | erenhot
# Processing Record 37 of Set 5 | mayya
# Processing Record 38 of Set 5 | la palma
# Processing Record 39 of Set 5 | tabou
# Processing Record 40 of Set 5 | dombarovskiy
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | matara
# Processing Record 43 of Set 5 | novikovo
# Processing Record 44 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | huangnihe
# Processing Record 47 of Set 5 | vesyegonsk
# Processing Record 48 of Set 5 | cabedelo
# Processing Record 49 of Set 5 | san patricio
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | mayumba
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | mangrol
# Processing Record 4 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 6 | maiduguri
# Processing Record 6 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 6 | roura
# Processing Record 10 of Set 6 | paramonga
# Processing Record 11 of Set 6 | cidreira
# Processing Record 12 of Set 6 | tessalit
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | bandraboua
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | abaza
# Processing Record 18 of Set 6 | omsukchan
# Processing Record 19 of Set 6 | tongliao
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | fuyu
# Processing Record 22 of Set 6 | sabzevar
# Processing Record 23 of Set 6 | atasu
# Processing Record 24 of Set 6 | fengrun
# Processing Record 25 of Set 6 | port keats
# Processing Record 26 of Set 6 | zhanaozen
# Processing Record 27 of Set 6 | kathmandu
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | micheweni
# Processing Record 30 of Set 6 | reconquista
# Processing Record 31 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 6 | port-cartier
# Processing Record 33 of Set 6 | strezhevoy
# Processing Record 34 of Set 6 | mitu
# Processing Record 35 of Set 6 | manta
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | gobabis
# Processing Record 38 of Set 6 | saskylakh
# Processing Record 39 of Set 6 | bangassou
# Processing Record 40 of Set 6 | porto velho
# Processing Record 41 of Set 6 | sorland
# Processing Record 42 of Set 6 | kankaanpaa
# Processing Record 43 of Set 6 | airai
# Processing Record 44 of Set 6 | ust-uda
# Processing Record 45 of Set 6 | kerema
# Processing Record 46 of Set 6 | guarapari
# Processing Record 47 of Set 6 | dandong
# Processing Record 48 of Set 6 | imphal
# Processing Record 49 of Set 6 | hobyo
# Processing Record 50 of Set 6 | ariquemes
# Processing Record 1 of Set 7 | la paz
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | ust-barguzin
# Processing Record 4 of Set 7 | dimitrovgrad
# Processing Record 5 of Set 7 | buala
# Processing Record 6 of Set 7 | singaraja
# Processing Record 7 of Set 7 | wadi maliz
# Processing Record 8 of Set 7 | tamandare
# Processing Record 9 of Set 7 | saint-leu
# Processing Record 10 of Set 7 | clovis
# Processing Record 11 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 12 of Set 7 | todos santos
# Processing Record 13 of Set 7 | sobolevo
# Processing Record 14 of Set 7 | umm lajj
# Processing Record 15 of Set 7 | haapsalu
# Processing Record 16 of Set 7 | bintulu
# Processing Record 17 of Set 7 | saint anthony
# Processing Record 18 of Set 7 | methoni
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 7 | dillon
# Processing Record 22 of Set 7 | dikson
# Processing Record 23 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 24 of Set 7 | keetmanshoop
# Processing Record 25 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | eagle pass
# Processing Record 28 of Set 7 | vaitape
# Processing Record 29 of Set 7 | ossora
# Processing Record 30 of Set 7 | zambezi
# Processing Record 31 of Set 7 | honningsvag
# Processing Record 32 of Set 7 | los llanos de aridane
# Processing Record 33 of Set 7 | bilma
# Processing Record 34 of Set 7 | rossano
# Processing Record 35 of Set 7 | gilgit
# Processing Record 36 of Set 7 | franklin
# Processing Record 37 of Set 7 | anito
# Processing Record 38 of Set 7 | novovoronezh
# Processing Record 39 of Set 7 | kangaatsiaq
# Processing Record 40 of Set 7 | kot addu
# Processing Record 41 of Set 7 | newport
# Processing Record 42 of Set 7 | mirpur sakro
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | samarai
# Processing Record 45 of Set 7 | gouyave
# Processing Record 46 of Set 7 | praia
# Processing Record 47 of Set 7 | alyangula
# Processing Record 48 of Set 7 | codajas
# Processing Record 49 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 50 of Set 7 | iqaluit
# Processing Record 1 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 8 | ossipee
# Processing Record 3 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 8 | calabozo
# Processing Record 5 of Set 8 | renfrew
# Processing Record 6 of Set 8 | north bend
# Processing Record 7 of Set 8 | ternovka
# Processing Record 8 of Set 8 | te anau
# Processing Record 9 of Set 8 | olinda
# Processing Record 10 of Set 8 | moree
# Processing Record 11 of Set 8 | neuquen
# Processing Record 12 of Set 8 | abu samrah
# Processing Record 13 of Set 8 | balkhash
# Processing Record 14 of Set 8 | sitka
# Processing Record 15 of Set 8 | kiboga
# Processing Record 16 of Set 8 | el paso
# Processing Record 17 of Set 8 | tarnos
# Processing Record 18 of Set 8 | sebeta
# Processing Record 19 of Set 8 | torbay
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | kayerkan
# Processing Record 22 of Set 8 | agutaya
# Processing Record 23 of Set 8 | truro
# Processing Record 24 of Set 8 | thunder bay
# Processing Record 25 of Set 8 | estelle
# Processing Record 26 of Set 8 | goure
# Processing Record 27 of Set 8 | boyolangu
# Processing Record 28 of Set 8 | gremyachye
# City not found. Skipping...
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | khandyga
# Processing Record 31 of Set 8 | nikolayevka
# Processing Record 32 of Set 8 | kuytun
# Processing Record 33 of Set 8 | osorno
# Processing Record 34 of Set 8 | pangnirtung
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | marawi
# Processing Record 37 of Set 8 | jacareacanga
# Processing Record 38 of Set 8 | vostok
# Processing Record 39 of Set 8 | terney
# Processing Record 40 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 41 of Set 8 | santa cruz cabralia
# Processing Record 42 of Set 8 | mugur-aksy
# Processing Record 43 of Set 8 | kuah
# Processing Record 44 of Set 8 | mayo
# Processing Record 45 of Set 8 | salisbury
# Processing Record 46 of Set 8 | hasaki
# Processing Record 47 of Set 8 | inyonga
# Processing Record 48 of Set 8 | umm kaddadah
# Processing Record 49 of Set 8 | namibe
# Processing Record 50 of Set 8 | nizwa
# Processing Record 1 of Set 9 | englewood
# Processing Record 2 of Set 9 | codrington
# Processing Record 3 of Set 9 | sinnamary
# Processing Record 4 of Set 9 | mpika
# Processing Record 5 of Set 9 | yashkul
# Processing Record 6 of Set 9 | ambon
# Processing Record 7 of Set 9 | saint john
# Processing Record 8 of Set 9 | karratha
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | kutum
# Processing Record 11 of Set 9 | mopipi
# Processing Record 12 of Set 9 | khapa
# Processing Record 13 of Set 9 | san cristobal
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | inuvik
# Processing Record 16 of Set 9 | kumbo
# Processing Record 17 of Set 9 | poum
# Processing Record 18 of Set 9 | hamilton
# Processing Record 19 of Set 9 | tecoanapa
# Processing Record 20 of Set 9 | stornoway
# Processing Record 21 of Set 9 | sechura
# Processing Record 22 of Set 9 | noumea
# Processing Record 23 of Set 9 | turukhansk
# Processing Record 24 of Set 9 | natal
# Processing Record 25 of Set 9 | itupiranga
# Processing Record 26 of Set 9 | tairua
# Processing Record 27 of Set 9 | igarka
# Processing Record 28 of Set 9 | port lavaca
# Processing Record 29 of Set 9 | dukat
# Processing Record 30 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 9 | wattegama
# Processing Record 32 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 9 | husavik
# Processing Record 34 of Set 9 | ulety
# Processing Record 35 of Set 9 | ugoofaaru
# Processing Record 36 of Set 9 | horta
# Processing Record 37 of Set 9 | batagay-alyta
# Processing Record 38 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 39 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 9 | clyde
# Processing Record 41 of Set 9 | rantepao
# Processing Record 42 of Set 9 | sidi ali
# Processing Record 43 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 44 of Set 9 | lima
# Processing Record 45 of Set 9 | gubskaya
# Processing Record 46 of Set 9 | yabrud
# Processing Record 47 of Set 9 | rodeo
# Processing Record 48 of Set 9 | bairiki
# Processing Record 49 of Set 9 | le mars
# Processing Record 50 of Set 9 | buarcos
# Processing Record 1 of Set 10 | kostino
# Processing Record 2 of Set 10 | moose factory
# Processing Record 3 of Set 10 | niquelandia
# Processing Record 4 of Set 10 | arlit
# Processing Record 5 of Set 10 | midland
# Processing Record 6 of Set 10 | tezu
# Processing Record 7 of Set 10 | dhari
# Processing Record 8 of Set 10 | mattawa
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | arraial do cabo
# Processing Record 11 of Set 10 | bereda
# Processing Record 12 of Set 10 | naryan-mar
# Processing Record 13 of Set 10 | pakxan
# Processing Record 14 of Set 10 | riyadh
# Processing Record 15 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 10 | kashi
# Processing Record 17 of Set 10 | ouango
# Processing Record 18 of Set 10 | lorengau
# Processing Record 19 of Set 10 | porosozero
# Processing Record 20 of Set 10 | zhangjiakou
# Processing Record 21 of Set 10 | tocantins
# Processing Record 22 of Set 10 | whitefish
# Processing Record 23 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 10 | may pen
# Processing Record 25 of Set 10 | berlevag
# Processing Record 26 of Set 10 | vila velha
# Processing Record 27 of Set 10 | kaitangata
# Processing Record 28 of Set 10 | yelizovo
# Processing Record 29 of Set 10 | sept-iles
# Processing Record 30 of Set 10 | mahbubabad
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 10 | murakami
# Processing Record 34 of Set 10 | moyale
# Processing Record 35 of Set 10 | ambilobe
# Processing Record 36 of Set 10 | ballina
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | rio grande
# Processing Record 39 of Set 10 | yumen
# Processing Record 40 of Set 10 | talnakh
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | guerrero negro
# Processing Record 43 of Set 10 | manokwari
# Processing Record 44 of Set 10 | camargo
# Processing Record 45 of Set 10 | ponta delgada
# Processing Record 46 of Set 10 | kruszwica
# Processing Record 47 of Set 10 | rawson
# Processing Record 48 of Set 10 | wick
# Processing Record 49 of Set 10 | saint-augustin
# Processing Record 50 of Set 10 | kampene
# Processing Record 1 of Set 11 | uusikaupunki
# Processing Record 2 of Set 11 | santa rosalia
# Processing Record 3 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 11 | sola
# Processing Record 5 of Set 11 | tazovskiy
# Processing Record 6 of Set 11 | imbituba
# Processing Record 7 of Set 11 | sao geraldo do araguaia
# Processing Record 8 of Set 11 | isangel
# Processing Record 9 of Set 11 | sabya
# Processing Record 10 of Set 11 | kologriv
# Processing Record 11 of Set 11 | aci castello
# Processing Record 12 of Set 11 | tarko-sale
# Processing Record 13 of Set 11 | paamiut
# Processing Record 14 of Set 11 | lazo
# Processing Record 15 of Set 11 | hambantota
# Processing Record 16 of Set 11 | corning
# Processing Record 17 of Set 11 | boissevain
# Processing Record 18 of Set 11 | krasnozerskoye
# Processing Record 19 of Set 11 | meadow lake
# Processing Record 20 of Set 11 | ketchikan
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | alekseyevka
# Processing Record 23 of Set 11 | svarychiv
# Processing Record 24 of Set 11 | ures
# Processing Record 25 of Set 11 | conceicao do araguaia
# Processing Record 26 of Set 11 | siocon
# Processing Record 27 of Set 11 | belaya gora
# Processing Record 28 of Set 11 | at-bashi
# Processing Record 29 of Set 11 | portobelo
# Processing Record 30 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 11 | ndago
# Processing Record 32 of Set 11 | chaah
# Processing Record 33 of Set 11 | kirakira
# Processing Record 34 of Set 11 | guozhen
# Processing Record 35 of Set 11 | novi iskar
# Processing Record 36 of Set 11 | matelandia
# Processing Record 37 of Set 11 | inhambane
# Processing Record 38 of Set 11 | casa nova
# Processing Record 39 of Set 11 | dongsheng
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 11 | taltal
# Processing Record 43 of Set 11 | clearlake
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | mogadishu
# Processing Record 46 of Set 11 | guiratinga
# Processing Record 47 of Set 11 | chino valley
# Processing Record 48 of Set 11 | sokoni
# Processing Record 49 of Set 11 | the valley
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | palu
# Processing Record 2 of Set 12 | saint-ambroise
# Processing Record 3 of Set 12 | bhatkal
# Processing Record 4 of Set 12 | krasnoselkup
# Processing Record 5 of Set 12 | nikki
# Processing Record 6 of Set 12 | tome
# Processing Record 7 of Set 12 | salihorsk
# Processing Record 8 of Set 12 | nishihara
# Processing Record 9 of Set 12 | bikapur
# Processing Record 10 of Set 12 | bahir dar
# Processing Record 11 of Set 12 | la ronge
# Processing Record 12 of Set 12 | preobrazheniye
# Processing Record 13 of Set 12 | semnan
# Processing Record 14 of Set 12 | teahupoo
# Processing Record 15 of Set 12 | nicoya
# Processing Record 16 of Set 12 | rundu
# Processing Record 17 of Set 12 | son la
# Processing Record 18 of Set 12 | koppang
# Processing Record 19 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 12 | sayat
# Processing Record 21 of Set 12 | urucara
# Processing Record 22 of Set 12 | marquette
# Processing Record 23 of Set 12 | san vito dei normanni
# Processing Record 24 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 12 | alice springs
# Processing Record 26 of Set 12 | new ulm
# Processing Record 27 of Set 12 | port moresby
# Processing Record 28 of Set 12 | ardmore
# Processing Record 29 of Set 12 | eyl
# Processing Record 30 of Set 12 | khonsar
# City not found. Skipping...
# Processing Record 31 of Set 12 | parras
# City not found. Skipping...
# Processing Record 32 of Set 12 | poya
# Processing Record 33 of Set 12 | nabire
# Processing Record 34 of Set 12 | manacapuru
# Processing Record 35 of Set 12 | houma
# Processing Record 36 of Set 12 | muyezerskiy
# Processing Record 37 of Set 12 | ust-tarka
# Processing Record 38 of Set 12 | plaridel
# Processing Record 39 of Set 12 | verkhnyaya inta
# Processing Record 40 of Set 12 | bud
# Processing Record 41 of Set 12 | oistins
# Processing Record 42 of Set 12 | davila
# Processing Record 43 of Set 12 | san jose
# Processing Record 44 of Set 12 | hazorasp
# Processing Record 45 of Set 12 | alihe
# Processing Record 46 of Set 12 | ljungby
# Processing Record 47 of Set 12 | burgeo
# Processing Record 48 of Set 12 | penzance
# Processing Record 49 of Set 12 | amapa
# Processing Record 50 of Set 12 | gladstone
# Processing Record 1 of Set 13 | huarmey
# Processing Record 2 of Set 13 | saint-paul
# Processing Record 3 of Set 13 | sukhoverkovo
# City not found. Skipping...
# Processing Record 4 of Set 13 | baykit
# Processing Record 5 of Set 13 | sardarshahr
# Processing Record 6 of Set 13 | morristown
# Processing Record 7 of Set 13 | canto do buriti
# Processing Record 8 of Set 13 | sao gabriel
# Processing Record 9 of Set 13 | champerico
# Processing Record 10 of Set 13 | ust-kuyga
# Processing Record 11 of Set 13 | elko
# Processing Record 12 of Set 13 | kaka
# Processing Record 13 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 14 of Set 13 | itinga
# Processing Record 15 of Set 13 | sorong
# Processing Record 16 of Set 13 | kouroussa
# Processing Record 17 of Set 13 | elmira
# Processing Record 18 of Set 13 | belmonte
# Processing Record 19 of Set 13 | necochea
# Processing Record 20 of Set 13 | valleyview
# Processing Record 21 of Set 13 | seddon
# Processing Record 22 of Set 13 | pyaozerskiy
# Processing Record 23 of Set 13 | kismayo
# Processing Record 24 of Set 13 | kudat
# Processing Record 25 of Set 13 | jilib
# Processing Record 26 of Set 13 | mpanda
# Processing Record 27 of Set 13 | sabang
# Processing Record 28 of Set 13 | adrar
# Processing Record 29 of Set 13 | zinder
# Processing Record 30 of Set 13 | pandamatenga
# Processing Record 31 of Set 13 | krasnousolskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | vestmanna
# Processing Record 33 of Set 13 | chernyshevskiy
# Processing Record 34 of Set 13 | simpang
# Processing Record 35 of Set 13 | bagnols-sur-ceze
# Processing Record 36 of Set 13 | sungairaya
# Processing Record 37 of Set 13 | faya
# Processing Record 38 of Set 13 | labrea
# Processing Record 39 of Set 13 | pringsewu
# Processing Record 40 of Set 13 | llangefni
# Processing Record 41 of Set 13 | ler
# Processing Record 42 of Set 13 | pyatnitskoye
# Processing Record 43 of Set 13 | west bay
# Processing Record 44 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 13 | chara
# Processing Record 46 of Set 13 | ulaanbaatar
# Processing Record 47 of Set 13 | coquimbo
# Processing Record 48 of Set 13 | jos
# Processing Record 49 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 13 | frome
# Processing Record 1 of Set 14 | okha
# Processing Record 2 of Set 14 | piacabucu
# Processing Record 3 of Set 14 | plattsburgh
# Processing Record 4 of Set 14 | alamor
# Processing Record 5 of Set 14 | yankton
# Processing Record 6 of Set 14 | guiyang
# Processing Record 7 of Set 14 | contai
# Processing Record 8 of Set 14 | nantucket
# Processing Record 9 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 10 of Set 14 | leh
# Processing Record 11 of Set 14 | chifeng
# Processing Record 12 of Set 14 | vao
# Processing Record 13 of Set 14 | beloha
# Processing Record 14 of Set 14 | udimskiy
# Processing Record 15 of Set 14 | koppal
# Processing Record 16 of Set 14 | igrejinha
# Processing Record 17 of Set 14 | khani
# Processing Record 18 of Set 14 | dakar
# Processing Record 19 of Set 14 | axim
# Processing Record 20 of Set 14 | ndele
# Processing Record 21 of Set 14 | maragogi
# Processing Record 22 of Set 14 | blairmore
# Processing Record 23 of Set 14 | zhongshan
# Processing Record 24 of Set 14 | villablino
# Processing Record 25 of Set 14 | vondrozo
# Processing Record 26 of Set 14 | churumuco
# City not found. Skipping...
# Processing Record 27 of Set 14 | shimoda
# Processing Record 28 of Set 14 | venice
# Processing Record 29 of Set 14 | morondava
# Processing Record 30 of Set 14 | niamey
# Processing Record 31 of Set 14 | sungaipenuh
# Processing Record 32 of Set 14 | fenoarivo atsinanana
# Processing Record 33 of Set 14 | foca
# Processing Record 34 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 14 | antofagasta
# Processing Record 36 of Set 14 | killybegs
# Processing Record 37 of Set 14 | chicama
# Processing Record 38 of Set 14 | whitianga
# Processing Record 39 of Set 14 | ola
# Processing Record 40 of Set 14 | batticaloa
# Processing Record 41 of Set 14 | savannah bight
# Processing Record 42 of Set 14 | severnoye
# Processing Record 43 of Set 14 | roswell
# Processing Record 44 of Set 14 | dicabisagan
# Processing Record 45 of Set 14 | tomatlan
# Processing Record 46 of Set 14 | quatre cocos
# Processing Record 47 of Set 14 | sigli
# Processing Record 48 of Set 14 | voh
# Processing Record 49 of Set 14 | braco do norte
# Processing Record 50 of Set 14 | ostrovnoy
# Processing Record 1 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 15 | kyaikkami
# Processing Record 3 of Set 15 | halifax
# Processing Record 4 of Set 15 | nampula
# Processing Record 5 of Set 15 | yerbogachen
# Processing Record 6 of Set 15 | fujin
# Processing Record 7 of Set 15 | mandera
# Processing Record 8 of Set 15 | tual
# Processing Record 9 of Set 15 | balakovo
# Processing Record 10 of Set 15 | giyani
# Processing Record 11 of Set 15 | colquechaca
# Processing Record 12 of Set 15 | izhma
# Processing Record 13 of Set 15 | bambanglipuro
# Processing Record 14 of Set 15 | dumai
# Processing Record 15 of Set 15 | bolshaya irba
# City not found. Skipping...
# Processing Record 16 of Set 15 | shasta lake
# Processing Record 17 of Set 15 | urambo
# Processing Record 18 of Set 15 | progreso
# Processing Record 19 of Set 15 | dunmore
# Processing Record 20 of Set 15 | gagino
# Processing Record 21 of Set 15 | san luis
# Processing Record 22 of Set 15 | mislinja
# Processing Record 23 of Set 15 | nagtipunan
# Processing Record 24 of Set 15 | mount isa
# Processing Record 25 of Set 15 | alappuzha
# Processing Record 26 of Set 15 | deputatskiy
# Processing Record 27 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 28 of Set 15 | daugavpils
# Processing Record 29 of Set 15 | mandalgovi
# Processing Record 30 of Set 15 | koygorodok
# Processing Record 31 of Set 15 | clyde river
# Processing Record 32 of Set 15 | prince george
# Processing Record 33 of Set 15 | saryg-sep
# Processing Record 34 of Set 15 | babu
# Processing Record 35 of Set 15 | kirkenes
# Processing Record 36 of Set 15 | angoche
# Processing Record 37 of Set 15 | taperoa
# Processing Record 38 of Set 15 | cervo
# Processing Record 39 of Set 15 | jumla
# Processing Record 40 of Set 15 | mayuge
# Processing Record 41 of Set 15 | nago
# Processing Record 42 of Set 15 | malabo
# Processing Record 43 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 44 of Set 15 | bembereke
# Processing Record 45 of Set 15 | gainesville
# Processing Record 46 of Set 15 | kaeo
# Processing Record 47 of Set 15 | toamasina
# Processing Record 48 of Set 15 | qingdao
# Processing Record 49 of Set 15 | canutama
# Processing Record 50 of Set 15 | sayansk
# Processing Record 1 of Set 16 | majene
# Processing Record 2 of Set 16 | hay river
# Processing Record 3 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 16 | marzuq
# Processing Record 6 of Set 16 | nioro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     68.95        88          93
# 1    Coahuayana  18.7333 -103.6833     85.50        44          91
# 2      Pacifica  37.6138 -122.4869     77.65        63          40
# 3        Hobart -42.8794  147.3294     55.26        84         100
# 4        Avarua -21.2078 -159.7750     82.45        74          75
# ..          ...      ...       ...       ...       ...         ...
# 686     Sayansk  54.1088  102.1648     29.12        80         100
# 687      Majene  -3.5403  118.9707     76.98        85          91
# 688   Hay River  60.8156 -115.7999      3.16        71          75
# 689      Marzuq  14.4000   46.4667     69.98        33           2
# 690       Nioro  13.3500  -15.7500     79.72        39           6
#
#      Wind Speed Country                 Date Current Description
# 0         10.11      AU  2022-04-02 20:35:04     overcast clouds
# 1          7.65      MX  2022-04-02 20:35:04     overcast clouds
# 2          5.01      US  2022-04-02 20:35:05    scattered clouds
# 3          8.05      AU  2022-04-02 20:30:13     overcast clouds
# 4          5.75      CK  2022-04-02 20:35:05       broken clouds
# ..          ...     ...                  ...                 ...
# 686       11.41      RU  2022-04-02 20:51:40          light snow
# 687        2.68      ID  2022-04-02 20:56:08     overcast clouds
# 688        9.22      CA  2022-04-02 20:51:44       broken clouds
# 689        5.77      YE  2022-04-02 20:56:09           clear sky
# 690       11.65      GM  2022-04-02 20:56:09           clear sky
#
# [691 rows x 10 columns]

# %%
output_data_file = r"C:\Users\nemar\OneDrive\Desktop\Columbia Bootcamp\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
